# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
imdb_movies_india = pd.read_csv('imdb_movies_india.csv')
imdb_movies_india['year'] = imdb_movies_india['year'].abs()
imdb_movies_india
# Out:
#                        name    year duration                   genre  rating  \
# 0                       NaN     NaN      NaN                   Drama     NaN
# 1         ...And Once Again  2010.0  105 min                   Drama     NaN
# 2      ...Aur Pyaar Ho Gaya  1997.0  147 min  Comedy, Drama, Musical     4.7
# 3                 ...Yahaan  2005.0  142 min     Drama, Romance, War     7.4
# 4            .in for Motion  2008.0   59 min             Documentary     NaN
# ...                     ...     ...      ...                     ...     ...
# 15501   Zulm Ko Jala Doonga  1988.0      NaN                  Action     4.6
# 15502                 Zulmi  1999.0  129 min           Action, Drama     4.5
# 15503             Zulmi Raj  2005.0      NaN                  Action     NaN
# 15504         Zulmi Shikari  1988.0      NaN                  Action     NaN
# 15505          Zulm-O-Sitam  1998.0  130 min           Action, Drama     6.2
#
# ...

# %%
imdb_movies_india.shape
# Out:
# (15506, 10)

# %%
imdb_movies_india.info
# Out:
# <bound method DataFrame.info of                        name    year duration                   genre  rating  \
# 0                       NaN     NaN      NaN                   Drama     NaN
# 1         ...And Once Again  2010.0  105 min                   Drama     NaN
# 2      ...Aur Pyaar Ho Gaya  1997.0  147 min  Comedy, Drama, Musical     4.7
# 3                 ...Yahaan  2005.0  142 min     Drama, Romance, War     7.4
# 4            .in for Motion  2008.0   59 min             Documentary     NaN
# ...                     ...     ...      ...                     ...     ...
# 15501   Zulm Ko Jala Doonga  1988.0      NaN                  Action     4.6
# 15502                 Zulmi  1999.0  129 min           Action, Drama     4.5
# 15503             Zulmi Raj  2005.0      NaN                  Action     NaN
# 15504         Zulmi Shikari  1988.0      NaN                  Action     NaN
# 15505          Zulm-O-Sitam  1998.0  130 min           Action, Drama     6.2
#
# ...

# %%
imdb_movies_india.drop(imdb_movies_india[imdb_movies_india.year <= 2012.0 ].index, inplace=True)
imdb_movies_india.head(20)
# Out:
#                                    name  year duration  \
# 0                                   NaN   NaN      NaN
# 13                          108 Limited   NaN      NaN
# 20                             12 Years   NaN      NaN
# 34                                 1911   NaN      NaN
# 45                         2 GB Ki Life   NaN      NaN
# 56              21: Battle of Saragarhi   NaN      NaN
# 90                                4 Sum   NaN   96 min
# 109                    69 Reality in Us   NaN      NaN
# 119                         777 Charlie   NaN  136 min
# 127                     9 Roads 2 Peace   NaN      NaN
# 161                   A Song for No One   NaN      NaN
# 326                              Aakhet   NaN      NaN
# 461                           Aaryamaan   NaN  125 min
# 501                      Aati... Kya!!!   NaN  130 min
# 556        Abhi toh party shuru hui hai   NaN      NaN
# 564               Abhinav Bindra Biopic   NaN      NaN
# ...
